# %% [markdown]
# <a href="https://colab.research.google.com/github/dandds-coder/inmersion-datos/blob/main/Clase_02_4C_INMERSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AULA 02

# %%
# BIENVENIDO A NUESTRO PRIMER ENCUENTRO DE INMERSION DE DATOS == CLASE 02

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
inmuebles = pd.read_csv('/content/drive/MyDrive/ALURA_01/DATA/inmuebles_bogota.csv')

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 6011  Apartamento            Apartamento en venta en Cedritos             3
# 1425  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1512         Casa                       Casa en venta en Suba             3
# 93    Apartamento             Apartamento en venta en Usaquén             3
# 3082  Apartamento            Apartamento en venta en Cedritos             3
#
#       Baños  Área              Barrio                                 UPZ  \
# 6011      2    75            Cedritos                             Usaquén
# 1425      2    66  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1512      3   150                Suba                                Suba
# 93        2   152             Usaquén                             Usaquén
# 3082      2    96            Cedritos                             Usaquén
#
#                 Valor
# 6011    $ 420.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Área          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# ### Prueba de suma

# %%
inmuebles.Valor[0]+' ' +inmuebles.Valor[1] + ' ' + inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000 $ 670.000.000 $ 360.000.000
# 1      $ 360.000.000 $ 670.000.000 $ 670.000.000
# 2    $ 360.000.000 $ 670.000.000 $ 1.120.000.000
# 3      $ 360.000.000 $ 670.000.000 $ 890.000.000
# 4      $ 360.000.000 $ 670.000.000 $ 970.000.000
# Name: Valor, dtype: object

# %% [markdown]
# /* separacion de cadena de string */

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %% [markdown]
# # Separar con Expand para que se un nuevo valor en dataframe separado en 2

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %% [markdown]
# # agregamos al dataframe 2 nuevas columnas Moneda y Precio (valor numerico) con un sample 3

# %%
valor = inmuebles.Valor.str. split(expand=True)
inmuebles['Moneda']= valor [0]
inmuebles['Precio']= valor [1]
inmuebles.sample(3)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 823   Apartamento  Apartamento en venta en Rafael Uribe Uribe             3
# 9336  Apartamento            Apartamento en venta en Cedritos             3
# 2878  Apartamento                Apartamento en venta en Bosa             3
#
#       Baños  Área              Barrio            UPZ          Valor Moneda  \
# 823       2    72  Rafael Uribe Uribe  Los Alcázares  $ 330.000.000      $
# 9336      3   120            Cedritos        Usaquén  $ 722.000.000      $
# 2878      1    47                Bosa   Bosa Central  $ 136.000.000      $
#
#            Precio
# 823   330.000.000
# 9336  722.000.000
# 2878  136.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Área          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# # vamos a substituir los puntos en Precio

# %%
inmuebles['Precio']= inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio
# 0    $ 360.000.000      $   360000000
# ...

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %% [markdown]
# # Ahora vamos a cambiar el str (obj) Precio a Tipo float

# %%
inmuebles['Precio_Millon']=inmuebles.Precio.astype('float')/1000000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Baños          9520 non-null   int64
#  4   Área           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 6568         Casa                    Casa en venta en Usaquén             3
# 7067  Apartamento        Apartamento en venta en Los Mártires             2
# 7342  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 2067         Casa                       Casa en venta en Suba             4
# 2383         Casa                Casa en venta en Teusaquillo             3
#
#       Baños  Área              Barrio                                 UPZ  \
# 6568      3   127             Usaquén                             Usaquén
# 7067      1    40        Los Mártires                           La Sabana
# 7342      2    51  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 2067      3   130                Suba                                Suba
# 2383      4   420         Teusaquillo                         Teusaquillo
#
#                 Valor Moneda      Precio  Precio_Millon
# ...

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Baños           Área  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %% [markdown]
# |- count =  cantidad de valores en el dataframe
# |- mean = media /promedio
# |- std = desvio std
# |- min = el minimo
# |- 25% = 1er Quartil
# |- 50% = mediana o 2do Quartil
# |- 75% = 3er Quartil
# |- max = Valor maximo

# %% [markdown]
# # se arreglo los decimales a presentar en las metricas estadisticas de la funcio describe

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Baños      Área  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# # Tenemos un valor extremo en habitaciones 110 en el max, vamos a revisar cual registro es. usando la funcion loc para buscar ese datos en la columna habitaciones:

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Baños  Área    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %% [markdown]
# Respuesta: posible error de captura. ! casa con 110 Hab.¡ es un outlier asi como un min de 2.00 en area, veamos:

# %%
inmuebles.loc[inmuebles.Área == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Baños  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Área         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# Respuesta: posible error de captura

# %% [markdown]
# # Vamos a ver las funciones de Visualización

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Histograma la freq que aparece un dato, barra las veces que aparece afectada una variable

# %% [markdown]
# # Vamos a importar un par de nuevas herramientas para visualización

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,8))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon')
grafica.set_title('Distribución de valores de inmuebles en Bogota')

plt.show()

# %% [markdown]
# Corregimos visualizacion para 2000 millones

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True)
grafica.set_title('Distribución de valores de inmuebles en Bogota')

plt.xlim((50,1000))

plt.show()

# %% [markdown]
# El resultado anterior es la curva que mas se ajusta a la distribución que representa el Precio_Millon de los inmuebles.

# %%
# Como exportar esta figura (visualización)

# %%
plt.savefig('/content/drive/MyDrive/ALURA_01/DATA/valor_inmuebles_bogota.png')

# %%
# vamos agregar a esta visualización la dimensión de tipo de inmueble

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo')
grafica.set_title('Distribución de valores de inmuebles en Bogota')

plt.xlim((50,1000))

plt.show()

# %% [markdown]
# La visualización anterior no nos deja ver la muestra de tipo correctamente de los inmuebles, vamos ajustando la distribución.

# %% [markdown]
# #** DESAFIOS CLASE 02***
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles
# (Refinar el grafico: Titulos, Tamaño de Labels, Colores, conclusion de la información).
# 2.- Precio del m2 por barrio y hacer el grafico mas adecuado para esta nueva variable.

# %% [markdown]
# ## Desafio clase 02 - 01

# %%
inmuebles.loc[inmuebles['Tipo'].isin(['Oficina/Consultorio','Local','Bodega'])]
# Out:
#                      Tipo                                      Descripcion  \
# 107   Oficina/Consultorio   Oficina/Consultorio en venta en Ciudad Salitre
# 174   Oficina/Consultorio   Oficina/Consultorio en venta en Ciudad Salitre
# 330                 Local                      Local en venta en Chapinero
# 357                Bodega                 Bodega en venta en Puente Aranda
# 875   Oficina/Consultorio  Oficina/Consultorio en venta en Chico Reservado
# ...                   ...                                              ...
# 9348                Local                          Local en venta en Marly
# 9359                Local                  Local en venta en Puente Aranda
# 9466                Local                  Local en venta en Puente Aranda
# 9480                Local                   Local en venta en Las Delicias
# 9517                Local                       Local en venta en Restrepo
#
#       Habitaciones  Baños  Área           Barrio  \
# ...

# %%
inmuebles_3=inmuebles.loc[inmuebles['Tipo'].isin(['Oficina/Consultorio','Local','Bodega'])]

# %%
inmuebles_3
# Out:
#                      Tipo                                      Descripcion  \
# 107   Oficina/Consultorio   Oficina/Consultorio en venta en Ciudad Salitre
# 174   Oficina/Consultorio   Oficina/Consultorio en venta en Ciudad Salitre
# 330                 Local                      Local en venta en Chapinero
# 357                Bodega                 Bodega en venta en Puente Aranda
# 875   Oficina/Consultorio  Oficina/Consultorio en venta en Chico Reservado
# ...                   ...                                              ...
# 9348                Local                          Local en venta en Marly
# 9359                Local                  Local en venta en Puente Aranda
# 9466                Local                  Local en venta en Puente Aranda
# 9480                Local                   Local en venta en Las Delicias
# 9517                Local                       Local en venta en Restrepo
#
#       Habitaciones  Baños  Área           Barrio  \
# ...

# %%
plt.figure(figsize=(10,6))
grafica = sns.histplot(data=inmuebles_3, x='Precio_Millon', kde=True, hue='Tipo')
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
grafica.set_title('Distribución de valores de inmuebles en Bogota (3 tipos unicamente)', fontdict=title_font)
# plt.xlim((50,1000))
plt.show()

# %% [markdown]
# Conclusiones: Apartamentos y Casa son los mayores registros de toda esta muestra de datos, seleccione Oficina/Consultorio, Local y Bodega por que los registros son unicamente 111.

# %% [markdown]
# ## Desafio clase 02 - 01

# %%
inmuebles['Valorxm2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Área']

# %%
inmuebles.sample(10)
# Out:
#                      Tipo                                    Descripcion  \
# 5023          Apartamento            Apartamento en venta en Los Rosales
# 3125          Apartamento  Apartamento en venta en Ciudadela Colsubsidio
# 900                  Casa                      Casa en venta en Castilla
# 5162  Oficina/Consultorio        Oficina/Consultorio en venta en Usaquén
# 4837                 Casa                      Casa en venta en Madelena
# 8802          Apartamento      Apartamento en venta en Chapinero Central
# 1189          Apartamento           Apartamento en venta en Santa Teresa
# 1284          Apartamento               Apartamento en venta en Engativa
# 6463          Apartamento     Apartamento en venta en Zona Noroccidental
# 2549          Apartamento                Apartamento en venta en Kennedy
#
#       Habitaciones  Baños  Área                 Barrio  \
# 5023             3      3   145            Los Rosales
# ...

# %%
import numpy as np
from google.colab import autoviz

def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  import pandas as pd
  plt.subplots(figsize=(20 * figscale, 20 * figscale))
  df_2dhist = pd.DataFrame({
      x_label: grp[y_colname].value_counts()
      for x_label, grp in df.groupby(x_colname)
  })
  sns.heatmap(df_2dhist, cmap=mpl_palette_name)
  plt.xlabel(x_colname)
  plt.ylabel(y_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = heatmap(inmuebles, *['Valorxm2_Millon', 'Barrio'], **{})
chart
# Out:
# <img src="...

# %%
inmuebles[['Barrio', 'Valorxm2_Millon']]
# Out:
#                       Barrio  Valorxm2_Millon
# 0         Zona Noroccidental             5.14
# 1                   Castilla             3.94
# 2            Chico Reservado             7.78
# 3                    Usaquén             5.78
# 4                Bella Suiza             7.58
# ...                      ...              ...
# 9515                 Kennedy             4.14
# 9516  Parque Central Bavaria             6.70
# 9517                Restrepo             2.35
# 9518                Engativa             1.83
# 9519                 Tintala             2.79
#
# [9520 rows x 2 columns]

# %%
costo_inmuebles = inmuebles[['Barrio', 'Valorxm2_Millon']]

# %%
costo_inmuebles
# Out:
#                       Barrio  Valorxm2_Millon
# 0         Zona Noroccidental             5.14
# 1                   Castilla             3.94
# 2            Chico Reservado             7.78
# 3                    Usaquén             5.78
# 4                Bella Suiza             7.58
# ...                      ...              ...
# 9515                 Kennedy             4.14
# 9516  Parque Central Bavaria             6.70
# 9517                Restrepo             2.35
# 9518                Engativa             1.83
# 9519                 Tintala             2.79
#
# [9520 rows x 2 columns]

# %%
import numpy as np
from google.colab import autoviz

def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
  from matplotlib import pyplot as plt
  import seaborn as sns
  figsize = (20 * figscale, 5.8 * figscale)
  palette = list(sns.palettes.mpl_palette(mpl_palette_name))
  def _plot_series(series, series_name, series_index=0):
    if value_colname == 'count()':
      counted = (series[timelike_colname]
                 .value_counts()
                 .reset_index(name='counts')
                 .rename({'index': timelike_colname}, axis=1)
                 .sort_values(timelike_colname, ascending=True))
      xs = counted[timelike_colname]
      ys = counted['counts']
    else:
      xs = series[timelike_colname]
      ys = series[value_colname]
    plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

  fig, ax = plt.subplots(figsize=figsize, layout='constrained')
  df = df.sort_values(timelike_colname, ascending=True)
  if series_colname:
    for i, (series_name, series) in enumerate(df.groupby(series_colname)):
      _plot_series(series, series_name, i)
    fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
  else:
    _plot_series(df, '')
  sns.despine(fig=fig, ax=ax)
  plt.xlabel(timelike_colname)
  plt.ylabel(value_colname)
  return autoviz.MplChart.from_current_mpl_state()

chart = time_series_multiline(inmuebles, *['Barrio', 'Valorxm2_Millon', None], **{})
chart
# Out:
# <img src="...

# %% [markdown]
# # AULA 03

# %%
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Baños  Área              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valorxm2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78

# %%
inmuebles.groupby('Barrio').mean() # Agruaciones con media (promedio) solo aplica a campos númericos. Ojo media de media no es recomendable este calculo
# Out:
# <ipython-input-48-6706a35cf47b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   inmuebles.groupby('Barrio').mean() # Agruaciones con media (promedio) solo aplica a campos númericos. Ojo media de media no es recomendable este calculo
#                     Habitaciones  Baños   Área  Precio_Millon  Valorxm2_Millon
# Barrio
# Alameda                     3.00   2.00  97.00         580.00             5.98
# Alhambra                    3.00   2.94 190.41         752.35             4.33
# Andes Norte                 3.00   2.86 124.86         709.57             6.05
# Antonio Nariño              4.31   2.50 163.06         459.22             3.53
# Barrancas                   2.87   2.13  70.20         314.13             4.42
# ...

# %%
datos_barrio = inmuebles.groupby('Barrio').sum() # en este calculo se suman los valores del barrio , los juntamos y adicionamos
datos_barrio
# Out:
# <ipython-input-49-c4fe65b22c92>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   datos_barrio = inmuebles.groupby('Barrio').sum() # en este calculo se suman los valores del barrio , los juntamos y adicionamos
#                     Habitaciones  Baños    Área  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# ...

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Área'] # esta reagrupación recalculamos el promedio a la suma de los barrios en m2 totales
datos_barrio
# Out:
#                     Habitaciones  Baños    Área  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valorxm2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# ...

# %%
dict(datos_barrio['Valor_m2_Barrio']) # el nuevo valor de m2 por barrio, se mapean valores a nuestra columna actual
# Out:
# {'Alameda': 5.979381443298969,
#  'Alhambra': 3.95118937287612,
#  'Andes Norte': 5.683066361556064,
#  'Antonio Nariño': 2.816232272901495,
#  'Barrancas': 4.4748338081671415,
#  'Barrios Unidos': 2.9599171141243064,
#  'Bella Suiza': 6.2905507012394,
#  'Bellavista Occidental': 2.522711390635919,
#  'Bochica': 3.4078212290502794,
#  'Bogotá D.C': 5.212760277629472,
#  'Bosa': 2.6778451358697213,
#  'Bosa Piamonte': 1.175,
#  'Bosa Porvenir': 3.1666666666666665,
#  'Bosque De Pinos': 6.046475195822455,
#  'Bosque Popular': 3.864097363083164,
#  'Boyaca ': 2.637421499815294,
#  'Buenos Aires': 2.6,
#  'Candelaria La Nueva': 4.0625,
#  'Cantagallo': 5.71920581655481,
#  'Capellania': 4.316791690709752,
#  'Casablanca': 6.245421245421245,
#  'Castilla': 3.4035893155258763,
#  'Cedritos': 5.027419586695463,
#  'Cerros De Suba': 6.202830188679245,
#  'Chapinero': 4.58018576602501,
#  'Chapinero Alto': 6.4239336492891,
#  'Chapinero Central': 6.360286919831224,
# ...

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles ['Barrio'] # se inserta el valor nuevo de m2 barrio
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index #usamos value counts para tomar los primeros 10 indexado los barrios (TOP 10) de inmuebles a la venta

# %%
datos_barrio.reset_index(inplace=True) # nueva columnas de datos_barrio reseteamos el indexado

# %%
datos_barrio
# Out:
#                  Barrio  Habitaciones  Baños    Área  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valorxm2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %%
datos_barrio.query('Barrio in @top_barrios') #devuelve el top 10 de barrios en un dataframe
# Out:
#                  Barrio  Habitaciones  Baños    Área  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valorxm2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Valor_m2_Barrio", y="Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
ax.set_title('TOP 10 - Precio del m2 vs barrios con mayor numero de viviendas', fontdict=title_font)
# Out:
# Text(0.5, 1.0, 'TOP 10 - Precio del m2 vs barrios con mayor numero de viviendas')

# %% [markdown]
# El siguiente boxplot usa solamente datos_barrio con el Precio_Millon

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Precio_Millon", y="Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
ax.set_title('TOP 10 - Precio del m2 vs barrios con mayor numero de viviendas', fontdict=title_font)
plt.show()

# %% [markdown]
# Ahora la visualizacion que sigue mostraremos una distribución de la variable Valor_m2_Millon de la base completa no de los top 10, cambiamos base a inmuebles:

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valorxm2_Millon", data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
ax.set_title('TOP 10 - Valor de m2 (Millon) vs barrios con mayor numero de viviendas', fontdict=title_font)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valorxm2_Millon", data = inmuebles.query('Barrio in @top_barrios & Valorxm2_Millon < 15'))
ax.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
ax.set_title('TOP 10 - Valor de m2 (Millon) vs barrios con mayor numero de viviendas', fontdict=title_font)
plt.show() # aqui vamos a eliminar outliers que visualmente detectamos en la anterior visualizacion

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Área", data = inmuebles.query('Barrio in @top_barrios & Área < 500'))
ax.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
ax.set_title('TOP 10 - Area vs Barrios con mayor numero de viviendas', fontdict=title_font)
ax.grid()
plt.show() # aqui vamos a eliminar outliers que visualmente detectamos en la anterior visualizacion de la variable área

# %%
# Los autliers pueden afectar las respuestas de Machine Learning

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
ax.set_title('TOP 10 - Precio Millon vs Barrios con mayor numero de viviendas', fontdict=title_font)
ax.grid()
plt.show() # aqui vamos a eliminar outliers que visualmente detectamos en la anterior visualizacion de la variable área

# %% [markdown]
# ## *** DESAFIOS CLASE 03 ***

# %% [markdown]
# Dar un vistazo a la base de datos del DANE, comprender conceptualmente estas variables para entender mejor el contexto de esta base de datos;
# Organizar tu notebook para que tu proyecto quede mejor presentado.

# %% [markdown]
# # Creacion del dataframe DANE para la aula 04

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
identificacion = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Identificacion (Capitulo A).csv', sep = ';',encoding='latin-1')

# %%
identificacion
# IMPORTANTE: si no agregamos correctamente el encoding y la variable de separación, no se podran presentar correctament los datos en la tabla.
# Out:
#         DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0       3004346.00    11  11001      1           3.00         Santa Fe
# 1       3004347.00    11  11001      1          14.00     Los Mártires
# 2       3004348.00    11  11001      1           3.00         Santa Fe
# 3       3004349.00    11  11001      1           1.00          Usaquén
# 4       3004350.00    11  11001      1           1.00          Usaquén
# ...            ...   ...    ...    ...            ...              ...
# 106462  3004341.00    11  11001      1           3.00         Santa Fe
# 106463  3004342.00    11  11001      1           3.00         Santa Fe
# 106464  3004343.00    11  11001      1          14.00     Los Mártires
# 106465  3004344.00    11  11001      1           3.00         Santa Fe
# 106466  3004345.00    11  11001      1           3.00         Santa Fe
#
#         COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# ...

# %%
identificacion.MPIO.value_counts()
# Out:
# 11001    86504
# 25175     1613
# 25377     1610
# 25754     1460
# 25286     1440
# 25758     1429
# 25473     1292
# 25214     1215
# 25290      946
# 25430      873
# 25269      817
# 25899      792
# 25126      767
# 25817      713
# 25785      707
# 25099      694
# 25260      682
# 25740      658
# 25769      634
# 25295      625
# 25799      619
# 25898      377
# Name: MPIO, dtype: int64

# %%
# Tenemos 85,504 registros de Municipio correspondiente a BOGOTA.

# %%
identificacion = identificacion.loc[identificacion.MPIO == 11001]

# %%
identificacion.shape
# Out:
# (86504, 11)

# %% [markdown]
# # importaremos mas tablas

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Datos de la vivenda y su entorno (Capitulo B).csv', sep = ';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Condiciones habitacionales del hogar (Capitulo C).csv', sep = ';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Composicion del hogar y demografia (Capitulo E).csv', sep = ';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Educacion (Capitulo H).csv', sep = ';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Percepcion sobre las condiciones de vida y el desempeno institucional (Capitulo L).csv', sep = ';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Fuerza de trabajo (Capitulo K).csv', sep = ';',encoding='latin-1')
# Out:
# <ipython-input-74-58f2f7b8ee78>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Condiciones habitacionales del hogar (Capitulo C).csv', sep = ';',encoding='latin-1')
# <ipython-input-74-58f2f7b8ee78>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Composicion del hogar y demografia (Capitulo E).csv', sep = ';',encoding='latin-1')
# <ipython-input-74-58f2f7b8ee78>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Educacion (Capitulo H).csv', sep = ';',encoding='latin-1')
# ...

# %%
# vamos agregar columnas al dataframe identificacion revisando la llave que las relaciona en datos_dane con la tabla datos_b
datos_dane = pd.merge(identificacion,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-77-a8281422ec17>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %%
datos_dane.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004346.00    11  11001      1           3.00         Santa Fe
# 2  3004346.00    11  11001      1           3.00         Santa Fe
# 3  3004346.00    11  11001      1           3.00         Santa Fe
# 4  3004347.00    11  11001      1          14.00     Los Mártires
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 4          37.00                            Santa Isabel     11001162
#
#                            NOMBRE_ESTRATO  ... NPCEP22A  NPCEP24  NPCEP24A  \
# ...

# %% [markdown]
# # Resumen
# Hasta el momento tenemos integradas la base del DANE en el dataframe de datos_dane con los siguientes archivos csv:
#
# Identificacion (Capitulo A).csv
# Datos de la vivenda y su entorno (Capitulo B).csv
# Condiciones habitacionales del hogar (Capitulo C).csv
# Composicion del hogar y demografia (Capitulo E).csv

# %% [markdown]
# - Se continuara con la combinacion del dataframe DANE y la de INMUEBLES para cerrar el AULA 04.

# %% [markdown]
# #AULA 04

# %% [markdown]
# # BIENVENIDO A NUESTRO PRIMER ENCUENTRO DE INMERSION DE DATOS == CLASE 04 (FIN INTRODUCCION)

# %% [markdown]
# # Vamos aprender a construir un modelo de predicccion del valor de los inmuebles de bogota colombia, como parte de la inmerción de datos para formar parte de la gen de ciencia de datos del bootcamp de ALURA 2023 2da.
#
# https://www.youtube.com/watch?v=TMOsTr0sTeM&t=111s&ab_channel=AluraLatam

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
datos_dane_clean =  pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Clase_04/datos_dane.csv')

# %%
datos_dane_clean.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane_clean.shape # aqui esta las tabla datos_dane "reducidad" por el instructor de clase
# Out:
# (9857, 55)

# %%
datos_dane_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO',
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES',
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES',
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA',
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19',
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA',
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO',
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA',
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO',
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO',
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

# %%
datos_dane_clean = datos_dane_clean.rename(columns=dic_dane)

# %%
datos_dane_clean.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %%
# esta es una seleccion de datos del instructor de esta tabla anterior:
datos_dane_clean.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %%
datos = datos_dane_clean[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)

# %%
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
datos.NOMBRE_ESTRATO.value_counts() # Revisando si no se cambio algun numerico 2 en los datos de esta columna
# Out:
# Niza                                                   243
# SUBA: La Academia + Guaymaral + San José de Bavaria    212
# CHAPINERO: Chicó Lago + El Refugio                     210
# Los Libertadores                                       208
# Modelia                                                205
#                                                       ...
# Tunjuelito                                              26
# Lourdes                                                 25
# Localidad Chapinero resto                               21
# Localidad Usaquén resto                                 10
# Localidad Santa Fe resto                                 8
# Name: NOMBRE_ESTRATO, Length: 102, dtype: int64

# %%
# una ves mas vamos agrupar y promediar ahora la tabla datos
datos_tratados =  datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()

# %%
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %%
# vamos a conjuntar las tablas inmuebles y datos_tratados
pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
# LIsta la tabla para crear el modelo de ML:
datos_ml = pd.merge(inmuebles,datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Baños                     9520 non-null   int64
#  4   Área                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Valorxm2_Millon           9520 non-null   float64
#  12  Valor_m2_Barrio           9520 non-null   float64
# ...

# %% [markdown]
# IMPORTANTE UPZ remplaza la llave automaticamente NOMBRE_ESTRATO ya no aparece.

# %%
# Nos falta los datos de UPZ, vamos a traerlo:
upz = pd.read_csv('/content/drive/MyDrive/ALURA_01/DANE/Clase_04/cod_upz.csv')
upz.head()
# Out:
#                            NOMBRE_ESTRATO  COD_UPZ_GRUPO
# 0  SANTA FE: Las Nieves + Sagrado Corazón         814.00
# 1                            Santa Isabel          37.00
# 2   USAQUÉN: Country Club + Santa Bárbara         803.00
# 3      CHAPINERO: Pardo Rubio + Chapinero         816.00
# 4               Ciudad Salitre Occidental         110.00

# %%
# vamos hacer el marge para datos_ml:
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ', right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Baños  Área              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 26)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Baños                     9318 non-null   int64
#  4   Área                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Valorxm2_Millon           9318 non-null   float64
#  12  Valor_m2_Barrio           9318 non-null   float64
# ...

# %% [markdown]
# El dataset anterior datos_ml ya no tienen algun dato null o NaN. vamos a visualizar entonces.

# %%
plt.figure(figsize=(10,8))
ay = sns.boxplot(data=datos_ml, y="Precio_Millon")
ay.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
ay.set_title('Tabla de ML vs Precio Millon', fontdict=title_font)
ay.grid()
plt.show() # aqui vamos a eliminar outliers que visualmente detectamos en la anterior visualizacion de la variable área

# %% [markdown]
# Como en la visualizacion tenemos muchos outliers vamos a quitar parcialmente algunos datos, no sin antes asegurarnos que este resultado pueda afectar nuestro modelo de machine leaarninn, realizando la siguiente consulta:

# %%
datos_ml.query('Precio_Millon > 5000 | Precio_Millon < 60')
# Out:
#                      Tipo                                  Descripcion  \
# 207           Apartamento            Apartamento en venta en Chapinero
# 323                 Local                  Local en venta en Chapinero
# 702                  Casa                   Casa en venta en Chapinero
# 708                  Casa                   Casa en venta en Chapinero
# 829           Apartamento   Apartamento en venta en Zona Noroccidental
# 1371          Apartamento             Apartamento en venta en El Chicó
# 1414          Apartamento             Apartamento en venta en El Chicó
# 1429                Local             Local en venta en Quinta Camacho
# 1442                Local             Local en venta en Quinta Camacho
# 1518          Apartamento      Apartamento en venta en Chico Reservado
# 1532          Apartamento          Apartamento en venta en Chico Norte
# 1533          Apartamento          Apartamento en venta en Los Rosales
# ...

# %% [markdown]
# Los outliers se retiran para que los promedios y fq que aparecen estos datos mayores sea muy baja y no afecten la visulizacion o los datos en general.

# %%
# ahora vamos a omitir el intervalo anterior para obtener un nuevo dataframe de datos_ml:
datos_ml = datos_ml.query('Precio_Millon < 5000 | Precio_Millon > 60')

# %%
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 2            Casa         Casa en venta en Zona Noroccidental             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4            Casa         Casa en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
# vamos a revisra de nueva cuenta nuestro BOXPLOT
plt.figure(figsize=(10,8))
az = sns.boxplot(data=datos_ml, y="Precio_Millon")
az.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
az.set_title('Tabla de ML vs Precio Millon', fontdict=title_font)
az.grid()
plt.show() # aqui vamos a eliminar outliers que visualmente detectamos en la anterior visualizacion de la variable área

# %%
# Upsss no funciono , tendremos que cmabiar el or "|" por and "&":
# ahora vamos a omitir el intervalo anterior para obtener un nuevo dataframe de datos_ml:
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60') # vamos a cambiar Precio_Millon de < 5000 a <1200

# %%
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
# vamos a revisra de nueva cuenta nuestro BOXPLOT
plt.figure(figsize=(10,8))
aw = sns.boxplot(data=datos_ml, y="Precio_Millon")
aw.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
aw.set_title('Tabla de ML vs Precio Millon', fontdict=title_font)
aw.grid()
plt.show() # aqui vamos a eliminar outliers que visualmente detectamos en la anterior visualizacion de la variable área

# %% [markdown]
# Por fin reducimos los outliers, en la grafica anterior.

# %%
# Vamos a escalar el valor de los salarioas, por recomendacion del instructor
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# <ipython-input-155-4be13e3d3993>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %%
# vamos a revisra de nueva cuenta nuestro BOXPLOT
plt.figure(figsize=(10,8))
at = sns.boxplot(data=datos_ml, x='SALARIO_ANUAL_MI', y='Valorxm2_Millon')
# plt.ylim((0,15)) # ajusta el monto de Valorxm2_Millon
at.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
title_font = {'family': 'serif',
              'color':  'darkred',
              'weight': 'normal',
              'size': 16,
              }
at.set_title('Tabla de ML: SALARIO ANUAL AL MILLON  vs Precio m2 al Millon', fontdict=title_font)
at.grid()
plt.show() # ya quedo agusto con el nivel de outliers y vamos a graficar como influye el valor de m2

# %%
# debido a que nuestro objetivo es buscar una correlación, debemos cambiar por un scatterplot simple en ves de boxplot:
# vamos a revisra de nueva cuenta nuestro BOXPLOT
plt.figure(figsize=(10,8))
avw = sns.scatterplot(data=datos_ml, x='SALARIO_ANUAL_MI', y='Valorxm2_Millon')
plt.ylim((0,15)) # ajusta el monto de Valorxm2_Millon
#avw.tick_params(axis='x', rotation=45) # Vamos ajustar parametros de los titulos de X
#title_font = {'family': 'serif',
#              'color':  'darkred',
#              'weight': 'normal',
#              'size': 16,
#              }
#avw.set_title('Tabla de ML: SALARIO ANUAL AL MILLON  vs Precio m2 al Millon', fontdict=title_font)
#avw.grid()
plt.show() # aqui vamos a eliminar outliers que visualmente detectamos en la anterior visualizacion de la variable área

# %% [markdown]
# Este grafico anterior de dispersión debido a la FQ de los salarios personales anuales que no tiene correlacion con el precio de M2 en relacion con la UPZ

# %%
# Entonces vamos a revisar la correlación de las variables del dataframe de ML: datos_ml
datos_ml.corr()
# Out:
# <ipython-input-158-d4f9628f7d4a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datos_ml.corr()
#                           Habitaciones  Baños  Área  Precio_Millon  \
# Habitaciones                      1.00   0.44  0.03           0.18
# Baños                             0.44   1.00  0.04           0.66
# Área                              0.03   0.04  1.00           0.04
# Precio_Millon                     0.18   0.66  0.04           1.00
# Valorxm2_Millon                  -0.31  -0.03 -0.04           0.36
# Valor_m2_Barrio                  -0.21   0.13 -0.04           0.40
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01           0.32
# INSEGURIDAD                       0.13  -0.19 -0.00          -0.37
# TERMINALES_BUS                    0.08  -0.17 -0.01          -0.28
# ...

# %%
# Ahora para ver mejor la correlación, vamos a verlo a traves de un heatmap (Revisar que son correlaciones espurias, tarea):
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);
# Out:
# <ipython-input-159-aea83d8d689d>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %% [markdown]
# ## Ahora si vamos aplicar Sklearn para ML

# %%
from sklearn.linear_model import LinearRegression # (Analisis Supervisado)
from sklearn.model_selection import train_test_split # Libreria para separacion de datos de entrenamiento y datos de prueba

# %%
X = datos_ml [['COD_UPZ_GRUPO']] # aqui tomamos como referencia para un ejemplo para crear nuestra linea base
y = datos_ml ['Precio_Millon']

X_train, X_test,y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=99) #seudoaleatorio

# %%
X_train # 0.25 de datos
# Out:
#       COD_UPZ_GRUPO
# 1512         817.00
# 7864          85.00
# 6058          21.00
# 1683         817.00
# 2481          14.00
# ...             ...
# 6038          21.00
# 8875         102.00
# 2200          14.00
# 3883         803.00
# 8154          85.00
#
# [6234 rows x 1 columns]

# %%
X_test # 0.75 de datos
# Out:
#       COD_UPZ_GRUPO
# 6340          74.00
# 7805          85.00
# 4902          47.00
# 7041         100.00
# 2436          14.00
# ...             ...
# 3323          14.00
# 3945         803.00
# 5572          27.00
# 3633         803.00
# 3652         803.00
#
# [2079 rows x 1 columns]

# %%
y_train
# Out:
# 1512   1050.00
# 7864    129.00
# 6058    206.38
# 1683    650.00
# 2481    250.00
#          ...
# 6038    560.00
# 8875    560.00
# 2200    685.00
# 3883    850.00
# 8154    132.00
# Name: Precio_Millon, Length: 6234, dtype: float64

# %%
y_test
# Out:
# 6340   199.90
# 7805   120.80
# 4902   400.00
# 7041   340.00
# 2436   355.00
#         ...
# 3323   700.00
# 3945   510.00
# 5572   220.00
# 3633   420.00
# 3652   435.60
# Name: Precio_Millon, Length: 2079, dtype: float64

# %%
# Aqui aplicamos el modelo
modelo = LinearRegression() #aplicamos el generico

# %%
# ajustamos datos de entrenamiento
modelo.fit(X_train, y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
# Ahora la predicción del Modelo:
y_predict_test = modelo.predict(X_test)

# %%
# vamos ahora a validar nuestro modelo
from sklearn.metrics import mean_absolute_error, r2_score #error absoluto medio
baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_mae
# Out:
# 187.323609443345

# %%
baseline_r2 = r2_score(y_test, y_predict_test)
baseline_r2
# Out:
# 0.031111799984413713

# %% [markdown]
# NUESTRO MODELO NO ESTA FUNCIONANDO CORRECTAMENTE, HAY QUE CAMBIAR DE VARIABLES

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Baños']] #,'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA'

Y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 129.79569561829595 0.4710300116377151
# 134.0676755859009 0.4669568993620524

# %%
# Vamos adicionar mas variables para entrenar nuestro modelo:

X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Baños', 'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']] #,'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA'

Y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %%
# vamos a utilizar la predicción, cuanto nos va acostar un departamento metiendo los datos en orden
#'COD_UPZ_GRUPO','Habitaciones','Baños', 'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA': :
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])

# %% [markdown]
# # CONCLUSIONES: Disminuir los outliers da mayor porcentaje de respuesta el valor de r2 en los datos de prueba y entrenamiento.
# en el modelo de Sklearn para el analisis de datos

# %% [markdown]
# ### Fin de los cursos de inmersion
